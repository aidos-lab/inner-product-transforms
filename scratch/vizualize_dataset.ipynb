# %%
from types import SimpleNamespace
import torch 
import yaml 
import torchvision
import matplotlib.pyplot as plt

import json 
from datasets.shapenetcore import DataModule as ShapeNetCore
from datasets.shapenet import DataModule as ShapeNetCoreNormalized
from models.encoder import BaseModel
DEVICE = "cuda:0"

# with open(args.INPUT, encoding="utf-8") as stream:
#         run_dict = yaml.safe_load(stream)
#         run_config = json.loads(json.dumps(run_dict), object_hook=load_object)

def load_object(dct):
    return SimpleNamespace(**dct)

# with open("./configs/config_encoder_shapenet_chair.yaml","r") as f:
#     run_dict = yaml.safe_load(f)
#     config = json.loads(json.dumps(run_dict), object_hook=load_object)

# config.data.batch_size=64


with open("./configs/config_encoder_shapenet_airplane_scaled.yaml","r") as f:
    run_dict = yaml.safe_load(f)
    config = json.loads(json.dumps(run_dict), object_hook=load_object)

dm = ShapeNetCoreNormalized(config.data)

# model = BaseModel.load_from_checkpoint(f"./{config.trainer.save_dir}/{config.trainer.save_name}.ckpt").to(DEVICE)
# Out:
# C:\Users\ernst\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torch_geometric\data\dataset.py:239: UserWarning: The `pre_transform` argument differs from the one used in the pre-processed version of this dataset. If you want to make use of another pre-processing technique, pass `force_reload=True` explicitly to reload the dataset.
#   warnings.warn(
# Processing...
# Done!
# Processing...
# Done!
# Processing...
# Done!
# Processing...
# Done!

# %%
for idx, batch in enumerate(dm.train_dataloader()):
    batch = batch.cuda()
    print(batch.x.norm(dim=-1).max())
    # if batch.x.norm(dim=-1).max() > 5:
        # ect = model.layer(batch,batch.batch)
        # img = torchvision.utils.make_grid(ect.unsqueeze(1))
        # plt.imshow(img.cpu().permute(1, 2, 0))
        # plt.show()
# Out:
# tensor(1., device='cuda:0')
# tensor(1., device='cuda:0')
# tensor(1., device='cuda:0')
# tensor(1., device='cuda:0')
# tensor(1., device='cuda:0')
# tensor(1., device='cuda:0')
# tensor(1., device='cuda:0')
# tensor(1., device='cuda:0')
# tensor(1., device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1., device='cuda:0')
# tensor(1., device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1., device='cuda:0')
# tensor(1., device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1., device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1., device='cuda:0')
# tensor(1., device='cuda:0')
# tensor(1., device='cuda:0')
# tensor(1., device='cuda:0')
# tensor(1., device='cuda:0')
# tensor(1., device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1., device='cuda:0')
# tensor(1., device='cuda:0')
# tensor(1., device='cuda:0')
# tensor(1., device='cuda:0')
# tensor(1., device='cuda:0')
# tensor(1., device='cuda:0')
# tensor(1., device='cuda:0')
# ...

# %%
# ect_tmp = []
# for idx, batch in enumerate(dm.train_dataloader()):
#     batch = batch.cuda()
#     ect = model.layer(batch,batch.batch)
#     img = torchvision.utils.make_grid(ect.unsqueeze(1))
#     plt.imshow(img.cpu().permute(1, 2, 0))
#     plt.show()


# ect = torch.cat(ect_tmp,dim=0)

# ect.shape

# %%
plt.imshow(ect[7].cpu())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plt.imshow(ect[7].cpu())
#
# NameError: name 'ect' is not defined

# %%
64*3
# Out:
# 192
