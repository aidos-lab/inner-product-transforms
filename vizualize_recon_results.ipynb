# %%
import torch

from plotting import plot_recon_2d, plot_recon_3d

# %%
models = ["encoder_mnist"]


for model in models: 
    print(80*"#")
    print(f"### {model.upper()}")
    print(80*"#")
    recon_pcs = torch.load(f'./results/{model}/reconstructions.pt').cpu().detach().squeeze().numpy()
    reference_pcs = torch.load(f'./results/{model}/references.pt').cpu().detach().squeeze().numpy()

    plot_recon_2d(recon_pcs=recon_pcs,ref_pcs=reference_pcs)
# Out:
# ################################################################################
# ### ENCODER_MNIST
# ################################################################################

# %%
models = ["encoder_chair_sparse","rendered_chair"]

for model in models: 
    print(80*"#")
    print(f"### {model.upper()}")
    print(80*"#")
    recon_pcs =5* torch.load(f'./results/{model}/reconstructions.pt').cpu().detach().squeeze().numpy()
    reference_pcs =5* torch.load(f'./results/{model}/references.pt').cpu().detach().squeeze().numpy()

    plot_recon_3d(recon_pcs=recon_pcs,ref_pcs=reference_pcs,num_pc=10,offset=0)
# Out:
# ################################################################################
# ### ENCODER_CHAIR_SPARSE
# ################################################################################
# <PIL.Image.Image image mode=RGB size=2000x600>
# ################################################################################
# ### RENDERED_CHAIR
# ################################################################################
# <PIL.Image.Image image mode=RGB size=2000x600>
