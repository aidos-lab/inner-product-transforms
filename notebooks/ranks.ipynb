# %%
import pandas as pd 

df = pd.read_csv("gen.csv").set_index("model")
display(df)
# Out:
#            mmd-cd-airplane  mmd-emd-airplane  cov-cd-airplane  \
# model
# PointFlow           0.2243            0.3901            47.90
# SoftFlow            0.2309            0.3745            46.91
# Shape-GF            2.7030            0.6592            40.74
# SetVAE              0.2000            0.3670            43.70
# PVD                 0.2243            0.3803            48.88
# LION                0.2190            0.3720            47.16
# PSF                    NaN               NaN              NaN
# XCube                  NaN               NaN              NaN
# Ours                0.1901            0.3383            45.67
#
#            cov-emd-airplane  nna-cd-airplane  nna-emd-airplane  mmd-cd-chair  \
# model
# PointFlow             46.41            75.68             69.44         2.409
# SoftFlow              47.90            70.92             69.44         2.528
# Shape-GF              40.49            80.00             76.17         2.889
# ...

# %%
df.rank().to_latex()
# Out:
# '\\begin{tabular}{lrrrrrrrrrrrrrrrrrr}\n\\toprule\n & mmd-cd-airplane & mmd-emd-airplane & cov-cd-airplane & cov-emd-airplane & nna-cd-airplane & nna-emd-airplane & mmd-cd-chair & mmd-emd-chair & cov-cd-chair & cov-emd-chair & nna-cd-chair & nna-emd-chair & mmd-cd-car & mmd-emd-car & cov-cd-car & cov-emd-car & nna-cd-car & nna-emd-car \\\\\nmodel &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  \\\\\n\\midrule\nPointFlow & 4.500000 & 6.000000 & 6.000000 & 3.000000 & 7.000000 & 6.500000 & 2.000000 & 5.000000 & 3.000000 & 5.000000 & 7.000000 & 5.000000 & 3.000000 & 6.000000 & 4.000000 & 4.000000 & 7.000000 & 8.000000 \\\\\nSoftFlow & 6.000000 & 4.000000 & 4.000000 & 4.000000 & 3.000000 & 6.500000 & 3.000000 & 6.000000 & 2.000000 & 2.000000 & 6.000000 & 8.000000 & 6.000000 & 7.000000 & 3.000000 & 1.000000 & 8.000000 & 9.000000 \\\\\nShape-GF & 7.000000 & 7.000000 & 1.000000 & 1.000000 & 9.000000 & 8.000000 & 7.000000 & 7.000000 & 4.000000 & 3.000000 & 9.000000 & 9.000000 & 7.000000
# ...
