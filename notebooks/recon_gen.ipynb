# %%
import matplotlib.pyplot as plt
import torch

from shapesynthesis.layers.directions import (
    generate_directions,
    generate_uniform_directions,
)
from shapesynthesis.layers.ect import compute_ect_point_cloud
from shapesynthesis.loaders import load_config
from shapesynthesis.plotting import plot_recon_3d
from shapesynthesis.renderers.pointcloud import render_point_cloud



# Load the ground_truth and reconstructed ects.
ect_recon = torch.load("./0799.pt").view(-1,128,128).to(torch.float) / 128 -1 
# ect_gt = torch.load("./gt_ect.pt")


print(ect_recon.shape,ect_recon.min(),ect_recon.max())

plt.imshow(ect_recon[0].cpu().numpy())
# Out:
# torch.Size([16, 128, 128]) tensor(-0.0078) tensor(0.9922)

# %%
print(ect_recon.min(),ect_recon.max())
# Out:
# tensor(127, dtype=torch.uint8) tensor(255, dtype=torch.uint8)

# %%
# d = ect_recon - ect_gt

plt.imshow(d[3].squeeze().cpu().numpy())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 d = ect_recon - ect_gt
#       3 plt.imshow(d[3].squeeze().cpu().numpy())
#
# RuntimeError: The size of tensor a (410) must match the size of tensor b (64) at non-singleton dimension 0

# %%
torch.norm(d,dim=[1,2])[0]
# Out:
# tensor(1.3661, device='cuda:0')
