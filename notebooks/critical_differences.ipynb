# %%
# !pip install --upgrade pip setuptools wheel
# !pip install 'critdd @ git+https://github.com/mirkobunse/critdd'
# Out:
# Requirement already satisfied: pip in c:\users\ernst\appdata\local\programs\python\python310\lib\site-packages (23.0.1)
# Collecting pip
#   Using cached pip-25.0.1-py3-none-any.whl (1.8 MB)
# Requirement already satisfied: setuptools in c:\users\ernst\appdata\local\programs\python\python310\lib\site-packages (65.5.0)
# Collecting setuptools
#   Using cached setuptools-78.1.0-py3-none-any.whl (1.3 MB)
# Collecting wheel
#   Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# ERROR: To modify pip, please run the following command:
# C:\Users\Ernst\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip setuptools wheel
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Invalid requirement: "'critdd"
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from critdd import Diagram
import pandas as pd

# download example data
_URL = "https://raw.githubusercontent.com/hfawaz/cd-diagram/master/example.csv"
df = pd.read_csv(_URL).pivot(
    index = "dataset_name",
    columns = "classifier_name",
    values = "accuracy"
)

dg = df.head(n=1)
dg
# Out:
# classifier_name     clf1      clf2     clf3      clf4      clf5
# dataset_name
# dataset1         0.69011  0.523077  0.81978  0.483516  0.454945

# %%
# create a CD diagram from the Pandas DataFrame
diagram = Diagram(
    df.to_numpy(),
    treatment_names = df.columns,
    maximize_outcome = True
)

# inspect average ranks and groups of statistically indistinguishable treatments
diagram.average_ranks # the average rank of each treatment
diagram.get_groups(alpha=.05, adjustment="holm")

# export the diagram to a file
diagram.to_file(
    "example.tex",
    alpha = .05,
    adjustment = "holm",
    reverse_x = True,
    axis_options = {"title": "critdd"},
)
df.head()
# Out:
# c:\Users\Ernst\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_axis_nan_policy.py:531: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   res = hypotest_fun_out(*samples, **kwds)
# classifier_name      clf1      clf2      clf3      clf4      clf5
# dataset_name
# dataset1         0.690110  0.523077  0.819780  0.483516  0.454945
# dataset10        0.901449  0.266667  0.864493  0.848551  0.837681
# dataset11        0.535714  0.928571  1.000000  1.000000  1.000000
# dataset12        0.592000  0.596000  0.772000  0.576000  0.820000
# dataset13        0.664103  0.620513  0.841026  0.589744  0.794872

# %%
df_comparison = pd.read_csv("comparison.csv",header=0)
df_comparison_emd = df_comparison[["Model","AirplaneEMD","ChairEMD","CarEMD"]].set_index("Model").T
df_comparison_cd = df_comparison[["Model","AirplaneCD","ChairCD","CarCD"]].set_index("Model").T
df_comparison = df_comparison.set_index("Model").T

# df_comparison["AirplaneCD"]

# %%
# create a CD diagram from the Pandas DataFrame
diagram = Diagram(
    df_comparison.to_numpy(),
    treatment_names = df_comparison_cd.columns,
    maximize_outcome = True
)

# inspect average ranks and groups of statistically indistinguishable treatments
diagram.average_ranks # the average rank of each treatment
diagram.get_groups(alpha=.05, adjustment="holm")

# export the diagram to a file
diagram.to_file(
    "comparison.tex",
    alpha = .05,
    adjustment = "holm",
    reverse_x = True,
    axis_options = {"title": "critdd"},
)
df_comparison.head()
# Out:
# c:\Users\Ernst\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_axis_nan_policy.py:531: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   res = hypotest_fun_out(*samples, **kwds)
# c:\Users\Ernst\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_axis_nan_policy.py:531: UserWarning: Sample size too small for normal approximation.
#   res = hypotest_fun_out(*samples, **kwds)
# Model        PointFlow  SoftFlow  ShapeGF  SetVAE    PVD   LION    IPT
# AirplaneCD       75.68     70.92    80.00   75.31  73.82  67.41  79.30
# AirplaneEMD      69.44     69.44    76.17   77.65  64.81  61.23  50.00
# ChairCD          60.88     59.95    68.96   58.76  56.26  53.70  64.73
# ChairEMD         59.89     63.51    65.48   61.48  53.32  52.34  64.20
# CarCD            60.65     62.63    63.20   59.66  54.55  53.41  61.79

# %% [markdown]
# # CD

# %%
# create a CD diagram from the Pandas DataFrame
diagram = Diagram(
    df_comparison_cd.to_numpy(),
    treatment_names = df_comparison_cd.columns,
    maximize_outcome = True
)

# inspect average ranks and groups of statistically indistinguishable treatments
diagram.average_ranks # the average rank of each treatment
diagram.get_groups(alpha=.05, adjustment="holm")

# export the diagram to a file
diagram.to_file(
    "comparison_cd.tex",
    alpha = .05,
    adjustment = "holm",
    reverse_x = True,
    axis_options = {"title": "critdd"},
)
df_comparison_cd.head()
# Out:
# Model       PointFlow  SoftFlow  ShapeGF  SetVAE    PVD   LION    IPT
# AirplaneCD      75.68     70.92    80.00   75.31  73.82  67.41  79.30
# ChairCD         60.88     59.95    68.96   58.76  56.26  53.70  64.73
# CarCD           60.65     62.63    63.20   59.66  54.55  53.41  61.79

# %%
# create a CD diagram from the Pandas DataFrame
diagram = Diagram(
    df_comparison_emd.to_numpy(),
    treatment_names = df_comparison_emd.columns,
    maximize_outcome = True
)

# inspect average ranks and groups of statistically indistinguishable treatments
diagram.average_ranks # the average rank of each treatment
diagram.get_groups(alpha=.05, adjustment="holm")

# export the diagram to a file
diagram.to_file(
    "comparison_emd.tex",
    alpha = .05,
    adjustment = "holm",
    reverse_x = True,
    axis_options = {"title": "critdd"},
)
df_comparison_emd.head()
# Out:
# c:\Users\Ernst\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_axis_nan_policy.py:531: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   res = hypotest_fun_out(*samples, **kwds)
# c:\Users\Ernst\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_axis_nan_policy.py:531: UserWarning: Sample size too small for normal approximation.
#   res = hypotest_fun_out(*samples, **kwds)
# Model        PointFlow  SoftFlow  ShapeGF  SetVAE    PVD   LION    IPT
# AirplaneEMD      69.44     69.44    76.17   77.65  64.81  61.23  50.00
# ChairEMD         59.89     63.51    65.48   61.48  53.32  52.34  64.20
# CarEMD           62.36     64.71    56.53   61.48  53.83  51.14  61.65
